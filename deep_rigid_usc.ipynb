# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/ajoshiusc/brainsync/blob/master/deep_rigid_usc.ipynb)

# %%
#AUM
#Shree Ganeshaya Namaha
import tensorflow as tf
tf.test.gpu_device_name()
from skimage import transform as tf
from skimage.transform import resize, rotate
from skimage.color import rgb2gray
from skimage.io import imread
from keras.layers import Input,Conv2D,concatenate,MaxPooling2D,Flatten,Dense,Dropout
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras import backend as K
import numpy as np
from numpy.random import uniform
import matplotlib.pyplot as plt
from skimage.viewer import ImageViewer
import cv2
from scipy.ndimage.interpolation import map_coordinates
from scipy.ndimage.filters import gaussian_filter
import matplotlib.pyplot as plt

# %matplotlib inline

from google.colab import files
uploaded = files.upload()


K.set_image_data_format('channels_last')  # TF dimension ordering in this code

from keras import losses
img_rows = 256
img_cols = 256


#taken from: https://www.kaggle.com/bguberfain/elastic-transform-for-data-augmentation
# Function to distort image
def elastic_transform(image, alpha, sigma, alpha_affine, random_state=None):
    """Elastic deformation of images as described in [Simard2003]_ (with modifications).
    .. [Simard2003] Simard, Steinkraus and Platt, "Best Practices for
         Convolutional Neural Networks applied to Visual Document Analysis", in
         Proc. of the International Conference on Document Analysis and
         Recognition, 2003.

     Based on https://gist.github.com/erniejunior/601cdf56d2b424757de5
    """
    if random_state is None:
        random_state = np.random.RandomState(None)

    shape = image.shape
    shape_size = shape[:2]
    
    # Random affine
    center_square = np.float32(shape_size) // 2
    square_size = min(shape_size) // 3
    pts1 = np.float32([center_square + square_size, [center_square[0]+square_size, center_square[1]-square_size], center_square - square_size])
    pts2 = pts1 + random_state.uniform(-alpha_affine, alpha_affine, size=pts1.shape).astype(np.float32)
#    M = cv2.getAffineTransform(pts1, pts2)
#    image = cv2.warpAffine(image, M, shape_size[::-1], borderMode=cv2.BORDER_REFLECT_101)

    dx = gaussian_filter((random_state.rand(*shape) * 2 - 1), sigma) * alpha
    dy = gaussian_filter((random_state.rand(*shape) * 2 - 1), sigma) * alpha
    dz = np.zeros_like(dx)

    x, y = np.meshgrid(np.arange(shape[1]), np.arange(shape[0]))
    indices = np.reshape(y+dy, (-1, 1)), np.reshape(x+dx, (-1, 1))

    return map_coordinates(image, indices, order=1, mode='reflect').reshape(shape)



def get_rr_net():
    inputs = Input((img_rows, img_cols, 2))
    inp2 = Dropout(.3)(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inp2)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    dr4 = Dropout(.2)(pool3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(dr4)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)
    flat1 = Flatten()(conv5)
    d1= Dense(512,activation='relu')(flat1)
    dr1=Dropout(.3)(d1)
    d2= Dense(64,activation='relu')(dr1)

    out_theta = Dense(3)(d2)
#    conv_tx = Conv2D(1, (1, 1), activation=final_activation)(conv5)
#    conv_ty = Conv2D(1, (1, 1), activation=final_activation)(conv5)
#    conv_theta = Conv2D(1, (1, 1), activation='tanh')(conv5)

#    out_img = rotate(inputs,conv_theta)

    model = Model(inputs=[inputs], outputs=out_theta)

    model.compile(optimizer='adam', loss=losses.mean_squared_error, metrics=['mse'])

    return model


def gen_train_data(img, N=1024,  nodist=0):
    imgs_train = np.zeros((N, img.shape[0], img.shape[1], 2))
    noise = 0*uniform(low=-1,high=1,size=imgs_train.shape)
    out_train = np.zeros((N, 3))
    rot = uniform(low=-60, high=60, size=(N,1))
    tx = uniform(low=-100, high=100, size=(N,1))
    ty = uniform(low=-100, high=100, size=(N,1))
    out_train[:,0]=rot.squeeze()
    out_train[:,1]=tx.squeeze()
    out_train[:,2]=ty.squeeze()

    in_rot = uniform(low=-60, high=60, size=(N,1))
 
    for j in range(N):
      
#        img2 = tf.warp(img,aff)
        img2 = rotate(img, in_rot[j],mode='edge')
        img2 -= np.mean(img2)
        img2 /= np.std(img2)
        if nodist==0:
            img2 = elastic_transform(img2, img2.shape[1] * 1.2, img2.shape[1] * 0.08,img2.shape[1] * 0.08)
        
        imgs_train[j, :, :, 0] = img2 + (1.0-nodist)*noise[j,:,:,0]
       
        aff = tf.AffineTransform(rotation = (np.pi/180.0)*np.float(rot[j]), translation=(tx[j],ty[j]))

        #img3 = 10-1*np.tanh(img2) + 0*  noise[j,:,:,1]#
        img3 = 10-1*np.tanh(tf.warp(img2, aff, mode='edge')) +  (1.0-nodist)*noise[j,:,:,1]#
        
        if nodist == 0:
            img3 = elastic_transform(img3, img3.shape[1] * .2, img3.shape[1] * 0.08,img3.shape[1] * 0.08)

        img3 -= np.mean(img3)
        img3 /= np.std(img3)
        imgs_train[j, :, :, 1] = img3
        
        if 0:
            plt.imshow(img3)
            plt.show()
            
            plt.imshow(img2)
            plt.show()
             
    return imgs_train, out_train


def train_model():
    print('-'*30)
    print('Loading and preprocessing train data...')
    print('-'*30)
    img = resize(rgb2gray(imread('sample_brain.png')).astype('float32'),(img_rows,img_cols),mode='constant')
    mean = np.mean(img)  # mean for data centering
    std = np.std(img)  # std for data normalization

    img -= mean
    img /= std
    
    imgs_train, out_train = gen_train_data(img, 1024*2)

    print('Creating and compiling model...')
    rrmodel = get_rr_net()
    model_checkpoint = ModelCheckpoint('weights.h5', monitor='val_loss', save_best_only=True)

    print('Fitting Model')
    history = rrmodel.fit(imgs_train, out_train, batch_size=32, epochs=50, verbose=1,
                shuffle=True, validation_split=0.2,
                callbacks=[model_checkpoint])
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['mean_squared_error'])
    plt.plot(history.history['val_mean_squared_error'])
    plt.title('model fit mse')
    plt.ylabel('mse')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
    
def test_model():
    
    print('Test data...')
    img = resize(rgb2gray(imread('sample_brain.png')).astype('float32'),(img_rows,img_cols),mode='reflect')
    mean = np.mean(img)  # mean for data centering
    std = np.std(img)  # std for data normalization

    img -= mean
    img /= std

    rrmodel = get_rr_net()
    rrmodel.load_weights('weights.h5')

    imgs_test, out_test = gen_train_data(img, 4, nodist=1)
#    plt.imshow(np.absolute(imgs_test[0,:,:,0].squeeze()),cmap='gray')
#    plt.imshow(np.absolute(imgs_test[0,:,:,1].squeeze()),cmap='gray')

    pred_theta = rrmodel.predict(imgs_test, verbose=1)

    for jj in range(4):
        fig=plt.figure(figsize=(20,10)); 
        fig.add_subplot(1,3,1);ax = plt.gca(); ax.grid(False)
        plt.axis('off')
        plt.imshow(np.absolute(imgs_test[jj,:,:,0].squeeze()),cmap='gray')
        fig.add_subplot(1,3,2);ax = plt.gca(); ax.grid(False)
        plt.axis('off')
        plt.imshow(np.absolute(imgs_test[jj,:,:,1].squeeze()),cmap='gray')
        aff = tf.AffineTransform(rotation = (np.pi/180.0)*pred_theta[jj,0], translation=(pred_theta[jj,1],pred_theta[jj,2]))
        img2 = tf.warp(np.absolute(imgs_test[jj,:,:,0].squeeze()),aff)
        fig.add_subplot(1,3,3);ax = plt.gca(); ax.grid(False)
        plt.axis('off')
        plt.imshow(img2,cmap='gray')
        plt.show()
    
    
    print(pred_theta)
    print(out_test)



if __name__ == '__main__':
    train_model()
    test_model()
# Out:
#      <input type="file" id="files-9c21c0fe-13f1-4834-8e09-bb613874bc84" name="files[]" multiple disabled />
#      <output id="result-9c21c0fe-13f1-4834-8e09-bb613874bc84">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ------------------------------
# Loading and preprocessing train data...
# ------------------------------
# Creating and compiling model...
# Fitting Model
# Train on 1638 samples, validate on 410 samples
# Epoch 1/50
# 1638/1638 [==============================] - 30s 18ms/step - loss: 2697.7876 - mean_squared_error: 2697.7876 - val_loss: 2581.1522 - val_mean_squared_error: 2581.1522
# Epoch 2/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 2535.2587 - mean_squared_error: 2535.2587 - val_loss: 2412.3537 - val_mean_squared_error: 2412.3537
# Epoch 3/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 1607.7981 - mean_squared_error: 1607.7981 - val_loss: 1805.6899 - val_mean_squared_error: 1805.6899
# Epoch 4/50
#  800/1638 [=============>................] - ETA: 13s - loss: 1411.8052 - mean_squared_error: 1411.8052
# 1638/1638 [==============================] - 28s 17ms/step - loss: 1292.2666 - mean_squared_error: 1292.2666 - val_loss: 1367.9105 - val_mean_squared_error: 1367.9105
# Epoch 5/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 1014.0197 - mean_squared_error: 1014.0197 - val_loss: 1196.5740 - val_mean_squared_error: 1196.5740
# Epoch 6/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 831.2371 - mean_squared_error: 831.2371 - val_loss: 916.0869 - val_mean_squared_error: 916.0869
# Epoch 7/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 605.8386 - mean_squared_error: 605.8386 - val_loss: 677.7146 - val_mean_squared_error: 677.7146
# Epoch 8/50
#  928/1638 [===============>..............] - ETA: 11s - loss: 472.1125 - mean_squared_error: 472.1125
# 1638/1638 [==============================] - 28s 17ms/step - loss: 459.4140 - mean_squared_error: 459.4140 - val_loss: 577.5617 - val_mean_squared_error: 577.5617
# Epoch 9/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 362.8013 - mean_squared_error: 362.8013 - val_loss: 560.8045 - val_mean_squared_error: 560.8045
# Epoch 10/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 298.0984 - mean_squared_error: 298.0984 - val_loss: 594.9358 - val_mean_squared_error: 594.9358
# Epoch 11/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 242.3276 - mean_squared_error: 242.3276 - val_loss: 535.3244 - val_mean_squared_error: 535.3244
# Epoch 12/50
#  992/1638 [=================>............] - ETA: 10s - loss: 214.8687 - mean_squared_error: 214.8687
# 1638/1638 [==============================] - 28s 17ms/step - loss: 220.7302 - mean_squared_error: 220.7302 - val_loss: 519.3116 - val_mean_squared_error: 519.3116
# Epoch 13/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 180.2448 - mean_squared_error: 180.2448 - val_loss: 548.2907 - val_mean_squared_error: 548.2907
# Epoch 14/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 171.4941 - mean_squared_error: 171.4941 - val_loss: 506.4634 - val_mean_squared_error: 506.4634
# Epoch 15/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 175.6507 - mean_squared_error: 175.6507 - val_loss: 452.3936 - val_mean_squared_error: 452.3936
# Epoch 16/50
#  992/1638 [=================>............] - ETA: 10s - loss: 151.6146 - mean_squared_error: 151.6146
# 1638/1638 [==============================] - 28s 17ms/step - loss: 154.3183 - mean_squared_error: 154.3183 - val_loss: 522.5979 - val_mean_squared_error: 522.5979
# Epoch 17/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 129.3551 - mean_squared_error: 129.3551 - val_loss: 432.7462 - val_mean_squared_error: 432.7462
# Epoch 18/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 126.8468 - mean_squared_error: 126.8468 - val_loss: 567.9655 - val_mean_squared_error: 567.9655
# Epoch 19/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 114.7586 - mean_squared_error: 114.7586 - val_loss: 509.6623 - val_mean_squared_error: 509.6623
# Epoch 20/50
#  992/1638 [=================>............] - ETA: 10s - loss: 119.0928 - mean_squared_error: 119.0928
# 1638/1638 [==============================] - 28s 17ms/step - loss: 117.2835 - mean_squared_error: 117.2835 - val_loss: 433.9903 - val_mean_squared_error: 433.9903
# Epoch 21/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 111.1138 - mean_squared_error: 111.1138 - val_loss: 385.4423 - val_mean_squared_error: 385.4423
# Epoch 22/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 136.1689 - mean_squared_error: 136.1689 - val_loss: 464.1311 - val_mean_squared_error: 464.1311
# Epoch 23/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 111.0762 - mean_squared_error: 111.0762 - val_loss: 412.9142 - val_mean_squared_error: 412.9142
# Epoch 24/50
#  992/1638 [=================>............] - ETA: 10s - loss: 99.6391 - mean_squared_error: 99.6391
# 1638/1638 [==============================] - 28s 17ms/step - loss: 102.5268 - mean_squared_error: 102.5268 - val_loss: 395.9072 - val_mean_squared_error: 395.9072
# Epoch 25/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 104.1423 - mean_squared_error: 104.1423 - val_loss: 511.3389 - val_mean_squared_error: 511.3389
# Epoch 26/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 99.6100 - mean_squared_error: 99.6100 - val_loss: 482.6023 - val_mean_squared_error: 482.6023
# Epoch 27/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 101.8929 - mean_squared_error: 101.8929 - val_loss: 539.1964 - val_mean_squared_error: 539.1964
# Epoch 28/50
# 1024/1638 [=================>............] - ETA: 9s - loss: 107.4701 - mean_squared_error: 107.4701
# 1638/1638 [==============================] - 28s 17ms/step - loss: 101.0417 - mean_squared_error: 101.0417 - val_loss: 413.8111 - val_mean_squared_error: 413.8111
# Epoch 29/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 103.5347 - mean_squared_error: 103.5347 - val_loss: 406.8709 - val_mean_squared_error: 406.8709
# Epoch 30/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 93.9714 - mean_squared_error: 93.9714 - val_loss: 408.9566 - val_mean_squared_error: 408.9566
# Epoch 31/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 98.5272 - mean_squared_error: 98.5272 - val_loss: 432.2409 - val_mean_squared_error: 432.2409
# Epoch 32/50
# 1024/1638 [=================>............] - ETA: 9s - loss: 94.4063 - mean_squared_error: 94.4063
# 1638/1638 [==============================] - 28s 17ms/step - loss: 90.9502 - mean_squared_error: 90.9502 - val_loss: 511.9571 - val_mean_squared_error: 511.9571
# Epoch 33/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 90.9760 - mean_squared_error: 90.9760 - val_loss: 385.0328 - val_mean_squared_error: 385.0328
# Epoch 34/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 91.5780 - mean_squared_error: 91.5780 - val_loss: 397.4555 - val_mean_squared_error: 397.4555
# Epoch 35/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 86.4669 - mean_squared_error: 86.4669 - val_loss: 405.5010 - val_mean_squared_error: 405.5010
# Epoch 36/50
# 1056/1638 [==================>...........] - ETA: 9s - loss: 79.4427 - mean_squared_error: 79.4427
# 1638/1638 [==============================] - 28s 17ms/step - loss: 77.1089 - mean_squared_error: 77.1089 - val_loss: 409.8087 - val_mean_squared_error: 409.8087
# Epoch 37/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 76.9775 - mean_squared_error: 76.9775 - val_loss: 441.2350 - val_mean_squared_error: 441.2350
# Epoch 38/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 81.9241 - mean_squared_error: 81.9241 - val_loss: 398.8101 - val_mean_squared_error: 398.8101
# Epoch 39/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 80.4742 - mean_squared_error: 80.4742 - val_loss: 433.4646 - val_mean_squared_error: 433.4646
# Epoch 40/50
# 1056/1638 [==================>...........] - ETA: 9s - loss: 73.2140 - mean_squared_error: 73.2140
# 1638/1638 [==============================] - 28s 17ms/step - loss: 76.6488 - mean_squared_error: 76.6488 - val_loss: 362.9502 - val_mean_squared_error: 362.9502
# Epoch 41/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 73.5395 - mean_squared_error: 73.5395 - val_loss: 401.2167 - val_mean_squared_error: 401.2167
# Epoch 42/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 75.5957 - mean_squared_error: 75.5957 - val_loss: 366.5139 - val_mean_squared_error: 366.5139
# Epoch 43/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 83.9539 - mean_squared_error: 83.9539 - val_loss: 402.7495 - val_mean_squared_error: 402.7495
# Epoch 44/50
# 1056/1638 [==================>...........] - ETA: 9s - loss: 74.9308 - mean_squared_error: 74.9308
# 1638/1638 [==============================] - 28s 17ms/step - loss: 73.5113 - mean_squared_error: 73.5113 - val_loss: 408.7124 - val_mean_squared_error: 408.7124
# Epoch 45/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 66.3291 - mean_squared_error: 66.3291 - val_loss: 438.3949 - val_mean_squared_error: 438.3949
# Epoch 46/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 75.1934 - mean_squared_error: 75.1934 - val_loss: 409.5795 - val_mean_squared_error: 409.5795
# Epoch 47/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 77.5631 - mean_squared_error: 77.5631 - val_loss: 404.3603 - val_mean_squared_error: 404.3603
# Epoch 48/50
# 1056/1638 [==================>...........] - ETA: 9s - loss: 76.3796 - mean_squared_error: 76.3796
# 1638/1638 [==============================] - 28s 17ms/step - loss: 75.2958 - mean_squared_error: 75.2958 - val_loss: 356.1408 - val_mean_squared_error: 356.1408
# Epoch 49/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 72.1170 - mean_squared_error: 72.1170 - val_loss: 468.0578 - val_mean_squared_error: 468.0578
# Epoch 50/50
# 1638/1638 [==============================] - 28s 17ms/step - loss: 79.0876 - mean_squared_error: 79.0876 - val_loss: 419.1422 - val_mean_squared_error: 419.1422
# dict_keys(['val_loss', 'val_mean_squared_error', 'loss', 'mean_squared_error'])
# Test data...
# 4/4 [==============================] - 0s 48ms/step
# [[ 29.543608 -35.355648 -60.40075 ]
#  [ 20.934387  70.24394   -8.164754]
#  [ -2.983443 -63.449585 -60.594135]
#  [-41.739044  60.2252   -36.218586]]
# [[ 32.13598338 -41.96070859 -61.94667007]
#  [ 24.19641654  82.1027858  -22.7174952 ]
#  [ 14.42998139 -85.65488218 -95.51458315]
#  [-44.35811505  65.89172362 -21.72712906]]

# %%
from google.colab import files
files.download('weights.h5')
# Out:
# ----------------------------------------
# Exception happened during processing of request from ('::ffff:127.0.0.1', 48978, 0, 0)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.6/socketserver.py", line 696, in __init__
#     self.handle()
#   File "/usr/lib/python3.6/http/server.py", line 418, in handle
#     self.handle_one_request()
#   File "/usr/lib/python3.6/http/server.py", line 406, in handle_one_request
#     method()
#   File "/usr/lib/python3.6/http/server.py", line 639, in do_GET
#     self.copyfile(f, self.wfile)
#   File "/usr/lib/python3.6/http/server.py", line 800, in copyfile
#     shutil.copyfileobj(source, outputfile)
#   File "/usr/lib/python3.6/shutil.py", line 82, in copyfileobj
#     fdst.write(buf)
#   File "/usr/lib/python3.6/socketserver.py", line 775, in write
#     self._sock.sendall(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
# ----------------------------------------
